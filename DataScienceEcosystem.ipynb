# %% [markdown]
# # Data Science Tools and Ecosystem

# %% [markdown]
# ![2-title.png](attachment:image.png)

# %% [markdown]
# In this notebook, Data Science Tools and Ecosystem are summarized.

# %% [markdown]
# Some of the popular languages that Data Scientists use are:
# 1. Python
# 2. R
# 3. SQL
# 4. MongoDB

# %% [markdown]
# ![4-dslanguages.png](attachment:image.png)

# %% [markdown]
# Some of the commonly used libraries used by Data Scientists include:
# 1. seaborn
# 2. matplotlib
# 3. scikitlearn

# %% [markdown]
# ![5dslibraries.png](attachment:image.png)

# %% [markdown]
# | Data Science Tools            |
# |-------------------------------|
# | Jupyter Notebooks              |
# | RStudio                        |
# | Apache Zeppelin                |

# %% [markdown]
# ![6-dstools.png](attachment:image.png)

# %% [markdown]
# ### Below are a few examples of evaluating arithmetic expressions in Python.
#
# In Python, you can perform various arithmetic operations using basic operators like `+`, `-`, `*`, `/`, `**`, and `%`. Here are some examples:
#
# 1. Addition
# 2. Subtraction
# 3. Multiplication
# 4. Division
# 5. Exponentiation
# 6. Modulus

# %% [markdown]
# ![7-introarithmetic.png](attachment:image.png)

# %%
# This is a simple arithmetic expression to multiply then add integers
result = (3 * 4) + 5
result
# Out:
# 17

# %% [markdown]
# ![8-multiplyandaddintegers](attachment:image.png)

# %%
# This will convert 200 minutes to hours by dividing by 60
minutes = 200
hours = minutes / 60
hours
# Out:
# 3.3333333333333335

# %% [markdown]
# ![9-hourstominutes](attachment:image.png)

# %% [markdown]
# **Objectives:**
#
# - Understand basic arithmetic operations in Python.
# - Learn different formats of cells in Python
# - Learn ETL
# - Learn the Basic Of GitHub, R, Python

# %% [markdown]
# ![10-objectives](attachment:image.png)

# %% [markdown]
# ## Author
#
# Bryan

# %% [markdown]
# ![11-authordetails.png](attachment:image.png)
